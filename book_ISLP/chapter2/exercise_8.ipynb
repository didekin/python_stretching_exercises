# %%
import  pandas as pd
from matplotlib.pyplot import subplots

# %%
college = pd.read_csv('../data/College.csv')
college
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college1 = pd.read_csv('../data/College.csv', index_col=0)
college1
# Out:
#           Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# Private
# Yes       1660    1232     721         23         52         2885
# Yes       2186    1924     512         16         29         2683
# Yes       1428    1097     336         22         50         1036
# Yes        417     349     137         60         89          510
# Yes        193     146      55         16         44          249
# ...        ...     ...     ...        ...        ...          ...
# No        2197    1515     543          4         26         3089
# Yes       1959    1805     695         24         47         2849
# Yes       2097    1915     695         34         61         2793
# Yes      10705    2453    1317         95         99         5217
# Yes       2989    1855     691         28         63         2988
#
#          P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# Private
# Yes              537      7440        3300    450      2200   70        78
# ...

# %%
college[['Outstate']].describe()
# Out:
#            Outstate
# count    777.000000
# mean   10440.669241
# std     4023.016484
# min     2340.000000
# 25%     7320.000000
# 50%     9990.000000
# 75%    12925.000000
# max    21700.000000

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']], figsize=(9,7))
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
fig1, ax1 = subplots()
college.boxplot('Outstate', by='Private', ax=ax1);

# %%
college.Top10perc
# Out:
# 0      23
# 1      16
# 2      22
# 3      60
# 4      16
#        ..
# 772     4
# 773    24
# 774    34
# 775    95
# 776    28
# Name: Top10perc, Length: 777, dtype: int64

# %%
college['Elite'] = pd.cut(college['Top10perc'], [0, 50,100], labels=['No', 'Yes'])
college.Elite
# Out:
# 0       No
# 1       No
# 2       No
# 3      Yes
# 4       No
#       ...
# 772     No
# 773     No
# 774     No
# 775    Yes
# 776     No
# Name: Elite, Length: 777, dtype: category
# Categories (2, object): ['No' < 'Yes']

# %%
college.Elite.value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
fig2, ax2 = subplots()
college.boxplot('Outstate', by='Elite', ax=ax2);

# %%
college.Top10perc.value_counts()
# Out:
# Top10perc
# 20    37
# 10    35
# 12    32
# 16    31
# 25    28
#       ..
# 66     1
# 79     1
# 74     1
# 80     1
# 81     1
# Name: count, Length: 82, dtype: int64

# %%
college.Outstate.value_counts()
# Out:
# Outstate
# 6550     13
# 8400      5
# 10500     5
# 8840      5
# 10800     4
#          ..
# 15884     1
# 6797      1
# 11520     1
# 19840     1
# 4990      1
# Name: count, Length: 640, dtype: int64

# %%
college.Apps.value_counts()
# Out:
# Apps
# 663     3
# 1006    3
# 440     3
# 1209    2
# 2096    2
#        ..
# 4302    1
# 1216    1
# 1130    1
# 3540    1
# 713     1
# Name: count, Length: 711, dtype: int64

# %%
college.Accept.value_counts()
# Out:
# Accept
# 452     4
# 405     3
# 888     3
# 562     3
# 384     3
#        ..
# 2314    1
# 1515    1
# 1915    1
# 2453    1
# 349     1
# Name: count, Length: 693, dtype: int64

# %%
fig3, ax3 = subplots(2,2)
college.hist('Top10perc', color='red', bins=5, ax=ax3[0,0])
college.hist('Outstate', color='blue', bins=10, ax=ax3[0,1])
college.hist('Apps', color='green', bins=6, ax=ax3[1,0])
college.hist('Accept', color='yellow', bins=8, ax=ax3[1,1]);
