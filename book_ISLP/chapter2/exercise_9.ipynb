# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Dropping rows with missing values:

# %%
autos = pd.read_csv('../data/Auto.csv')
autos = autos.dropna()
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
desc_autos = autos.describe()
desc_autos[desc_autos.axes[0].isin(['max', 'min'])]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# min   9.0        3.0          68.0        46.0  1613.0           8.0  70.0
# max  46.6        8.0         455.0       230.0  5140.0          24.8  82.0
#
#      origin
# min     1.0
# max     3.0

# %%
desc_autos[desc_autos.axes[0].isin(['mean', 'std'])]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# mean  23.445918   5.471939    194.411990  104.469388  2977.584184
# std    7.805007   1.705783    104.644004   38.491160   849.402560
#
#       acceleration       year    origin
# mean     15.541327  75.979592  1.576531
# std       2.758864   3.683737  0.805518

# %%
print(autos.index)
print('Rows from 10 to 85')
autos[10:86]
# Out:
# RangeIndex(start=0, stop=392, step=1)
# Rows from 10 to 85
#      mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 10  15.0          8         383.0         170    3563          10.0    70
# 11  14.0          8         340.0         160    3609           8.0    70
# 12  15.0          8         400.0         150    3761           9.5    70
# 13  14.0          8         455.0         225    3086          10.0    70
# 14  24.0          4         113.0          95    2372          15.0    70
# ..   ...        ...           ...         ...     ...           ...   ...
# 81  23.0          4         120.0          97    2506          14.5    72
# 82  28.0          4          98.0          80    2164          15.0    72
# 83  27.0          4          97.0          88    2100          16.5    72
# 84  13.0          8         350.0         175    4100          13.0    73
# 85  14.0          8         304.0         150    3672          11.5    73
#
# ...

# %%
autos_10_85_out = autos[(autos.index <= 10) | (autos.index > 85)]
autos_10_85_out
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
autos_10_85_out.describe().loc[['min', 'max', 'mean', 'std'], :]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# min   11.000000   3.000000     68.000000   46.000000  1649.000000
# max   46.600000   8.000000    455.000000  230.000000  4997.000000
# mean  24.377918   5.381703    188.129338  101.066246  2938.511041
# std    7.868594   1.658135    100.557303   36.106716   811.352128
#
#       acceleration       year    origin
# min       8.500000  70.000000  1.000000
# max      24.800000  82.000000  3.000000
# mean     15.699369  77.113565  1.599369
# std       2.728541   3.144169  0.819308

# %%
for method_name in dir(autos.plot):
   if not method_name.startswith("_"):
       print(method_name)
# Out:
# area
# bar
# barh
# box
# density
# hexbin
# hist
# kde
# line
# pie
# scatter

# %%
pd.plotting.scatter_matrix(autos, figsize=(12,12))
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='horsepower', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>,
#         <Axes: xlabel='origin', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>,
#         <Axes: xlabel='horsepower', ylabel='cylinders'>,
#         <Axes: xlabel='weight', ylabel='cylinders'>,
#         <Axes: xlabel='acceleration', ylabel='cylinders'>,
#         <Axes: xlabel='year', ylabel='cylinders'>,
#         <Axes: xlabel='origin', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
# ...

# %%
autos.plot.scatter(x='weight', y='mpg')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
autos.plot.scatter(x='horsepower', y='mpg')
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
autos.plot.scatter(x='displacement', y='mpg')
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>
