# %%
import numpy as np
import pandas as pd
from IPython.core.pylabtools import figsize
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm as anova

# %%
dir()
# Out:
# ['In',
#  'Out',
#  'VIF',
#  '_',
#  '_3',
#  '_5',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_pydevd_bundle',
#  'anova',
#  'exit',
#  'figsize',
#  'get_ipython',
#  'np',
#  'open',
#  'pd',
#  'pydev_jupyter_vars',
#  'quit',
#  'remove_imported_pydev_package',
#  'sm',
#  'subplots',
#  'sys']

# %%
A = np.array([3,5,11])
dir(A)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_namespace__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__buffer__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
# ...

# %%
A.sum()
# Out:
# np.int64(19)

# %% [markdown]
# SIMPLE LINEAR REGRESSION

# %%
boston = pd.read_csv('../data/Boston.csv')
boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# lstat = lower status of the population (percent).

# %%
X = pd.DataFrame({'intercept': np.ones(boston.shape[0]), 'lstat':boston['lstat']})
X[:4]
# Out:
#    intercept  lstat
# 0        1.0   4.98
# 1        1.0   9.14
# 2        1.0   4.03
# 3        1.0   2.94

# %% [markdown]
# medv = median value of owner-occupied homes in $1000s.

# %%
y = boston['medv']
model = sm.OLS(y, X)
results = model.fit()
dir(results)
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abat_diagonal',
#  '_cache',
#  '_data_attr',
#  '_data_in_cache',
#  '_get_robustcov_results',
#  '_get_wald_nonlinear',
#  '_is_nested',
#  '_transform_predict_exog',
#  '_use_t',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
# ...

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     601.6
# Date:                Fri, 24 Oct 2025   Prob (F-statistic):           5.08e-88
# Time:                        13:11:04   Log-Likelihood:                -1641.5
# No. Observations:                 506   AIC:                             3287.
# Df Residuals:                     504   BIC:                             3295.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     34.5538      0.563     61.415      0.000      33.448      35.659
# ...

# %%
results.params
# Out:
# intercept    34.553841
# lstat        -0.950049
# dtype: float64

# %%
X_test = pd.DataFrame({'lstat':[5,10,15]})
X_test = sm.add_constant(X_test)
results.get_prediction(X_test).summary_frame()
# Out:
#         mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  29.803594  0.405247      29.007412      30.599776     17.565675
# 1  25.053347  0.294814      24.474132      25.632563     12.827626
# 2  20.303101  0.290893      19.731588      20.874613      8.077742
#
#    obs_ci_upper
# 0     42.041513
# 1     37.279068
# 2     32.528459

# %% [markdown]
# Predictions for the means (confidence intervals).

# %%
results.get_prediction(X_test).conf_int(alpha=0.05)
# Out:
# array([[29.00741194, 30.59977628],
#        [24.47413202, 25.63256267],
#        [19.73158815, 20.87461299]])

# %% [markdown]
# Predictions for the observations (prediction intervals).

# %%
results.get_prediction(X_test).conf_int(obs=True, alpha=0.05)
# Out:
# array([[17.56567478, 42.04151344],
#        [12.82762635, 37.27906833],
#        [ 8.0777421 , 32.52845905]])

# %%
ax = boston.plot.scatter('lstat', 'medv')
x_range= ax.get_xlim()
interc = results.params.intercept
slope_out = results.params.lstat
y_pred_range = [x_range[0] * slope_out + interc, x_range[1] * slope_out + interc]
ax.axline((x_range[0], y_pred_range[0]), (x_range[1], y_pred_range[1]), color='red', linewidth=3)

# %%
ax = boston.plot.scatter('lstat', 'medv')
ax.plot(x_range, y_pred_range, color='red', linewidth=3);

# %% [markdown]
# Plotting residuals

# %%
ax2 = subplots(figsize=(12,9))[1]
ax2.scatter(results.fittedvalues, results.resid)
ax2.set_xlabel('Fitted values')
ax2.set_ylabel('Residuals')
ax2.axhline(y=0,color='yellow',ls='--' );
